# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.arange(-1000, 1000)
x
# Out:
# array([-1000,  -999,  -998, ...,   997,   998,   999], shape=(2000,))

# %%
x = np.linspace(-10, 10,1000)
y = np.sin(x)
plt.plot(x,y)

# %%
x = np.linspace(0,1,1000)
y = np.tan(x)
plt.plot(x, y)

# %%
x = np.linspace(-10,10,1000)
y = 1 / ( 1 + np.e**-x)
plt.plot(x , y)

# %%
x
y = np.e**x
plt.plot(x, y)

# %%
y = np.abs(x)
plt.plot(x, y)

# %%
y = np.log2(x)
plt.plot(x, y)
# Out:
# /var/folders/5f/scjcfk_97_n7zmjltnpm2mjc0000gn/T/ipykernel_75702/2854802922.py:1: RuntimeWarning: invalid value encountered in log2
#   y = np.log2(x)

# %%
y = 1 / (1 + np.e**(-x))
plt.plot(x , y)

# %%
y = x**2 + x - 10
plt.plot(x, y)

# %%
y = (x**3/3) + (x**2 / 2) - 2*x
plt.plot(x, y)

# %%
x = np.arange(-10000, 10000)
y = x**2 + x + 5
plt.plot(x, y)

# %%
plt.plot(x , -x**2 -7*x +3)

# %%
plt.plot(x, 8*x**2 - 4*x -2)
